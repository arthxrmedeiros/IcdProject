# %% [markdown]
# ## **Carregamento da base de dados**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "/home/carlos/Documentos/ufpb/icd/IcdProject/Dados Tratados/despesas.csv"
path_despesas_tratadas = "/home/carlos/Documentos/ufpb/icd/IcdProject/Dados Tratados/deputados_tratado_detalhado.csv"
df = pd.read_csv(path_despesas_tratadas)
# Out:
#      id                                                uri nomeParlamentar  \
# 0  1500  https://dadosabertos.camara.leg.br/api/v2/depu...      MÁRIO LIMA
# 1  1501  https://dadosabertos.camara.leg.br/api/v2/depu...  MAURÍCIO FRUET
#
#        siglaPartido                                         uriPartido  \
# 0  ['PMDB', 'PSB*']  https://dadosabertos.camara.leg.br/api/v2/part...
# 1  ['PMDB', 'MDB*']  https://dadosabertos.camara.leg.br/api/v2/part...
#
#   siglaUf idLegislatura                                            urlFoto  \
# 0  ['BA']  [48, 42, 47]  https://www.camara.leg.br/internet/deputado/ba...
# 1  ['PR']  [48, 46, 47]  https://www.camara.leg.br/internet/deputado/ba...
#
#   email sexo ultimaSituacao condicaoEleitoral   nomeEleitoral  \
# 0   NaN    M       Vacância           Titular      MÁRIO LIMA
# 1   NaN    M       Vacância           Titular  MAURÍCIO FRUET
#
#                  nomeCivil dataNascimento  falecido udNascimento escolaridade
# ...

# %% [markdown]
# ## **Características iniciais dos dados**

# %%
df.shape
# Out:
# (5190, 18)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5190 non-null   int64
#  1   uri                5190 non-null   str
#  2   nomeParlamentar    5190 non-null   str
#  3   siglaPartido       5190 non-null   str
#  4   uriPartido         5187 non-null   str
#  5   siglaUf            5190 non-null   str
#  6   idLegislatura      5190 non-null   str
#  7   urlFoto            5190 non-null   str
#  8   email              513 non-null    str
#  9   sexo               5190 non-null   str
#  10  ultimaSituacao     3832 non-null   str
#  11  condicaoEleitoral  5145 non-null   str
#  12  nomeEleitoral      5190 non-null   str
#  13  nomeCivil          5190 non-null   str
#  14  dataNascimento     5155 non-null   str
#  15  falecido           5190 non-null   int64
#  16  udNascimento       5106 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# id                      0
# uri                     0
# nomeParlamentar         0
# siglaPartido            0
# uriPartido              3
# siglaUf                 0
# idLegislatura           0
# urlFoto                 0
# email                4677
# sexo                    0
# ultimaSituacao       1358
# condicaoEleitoral      45
# nomeEleitoral           0
# nomeCivil               0
# dataNascimento         35
# falecido                0
# udNascimento           84
# escolaridade          435
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'uri', 'nomeParlamentar', 'siglaPartido', 'uriPartido', 'siglaUf',
#        'idLegislatura', 'urlFoto', 'email', 'sexo', 'ultimaSituacao',
#        'condicaoEleitoral', 'nomeEleitoral', 'nomeCivil', 'dataNascimento',
#        'falecido', 'udNascimento', 'escolaridade'],
#       dtype='str')

# %%
df.groupby(['sexo', 'siglaUf']).size()
# Out:
# sexo  siglaUf
# F     ['AC']           13
#       ['AL']            4
#       ['AM']            7
#       ['AP']           14
#       ['BA']           16
#                      ...
# M     ['SC']          183
#       ['SE']          100
#       ['SP', 'PE']      1
#       ['SP']          643
#       ['TO']           50
# Length: 80, dtype: int64

# %%
df.escolaridade.unique()
# Out:
# <StringArray>
# [             'Secundário',                'Superior',
#                        nan,          'Ensino Técnico',
#            'Pós-Graduação',                'Primário',
#      'Superior Incompleto',                'Mestrado',
#                 'Ginasial',   'Secundário Incompleto',
#                'Doutorado',      'Ensino Fundamental',
#             'Ensino Médio',     'Primário Incompleto',
#     'Doutorado Incompleto', 'Ensino Médio Incompleto',
#      'Mestrado Incompleto']
# Length: 17, dtype: str

# %%
df.siglaPartido.value_counts()
# Out:
# siglaPartido
# ['PMDB']                               423
# ['PSD']                                377
# ['PT']                                 309
# ['PTB']                                265
# ['ARENA']                              206
#                                       ...
# ['S.PART.', 'SOLIDARIEDADE', 'PSB']      1
# ['S.PART.', 'PL', 'MDB']                 1
# ['REPUBLICANOS', 'PV']                   1
# ['PDT', 'PODE']                          1
# ['REPUBLICANOS', 'UNIÃO']                1
# Name: count, Length: 920, dtype: int64

# %%
df.sexo.value_counts()
# Out:
# sexo
# M    4845
# F     345
# Name: count, dtype: int64

# %%
df.falecido.value_counts()
# Out:
# falecido
# 0    5151
# 1      39
# Name: count, dtype: int64

# %%
df.groupby("")
